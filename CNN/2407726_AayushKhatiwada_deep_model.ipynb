# %% [markdown]
# ### **Image Classification using Deep CNN Model**
# - Prepared By: **Aayush Khatiwada**
# - L6CG13 | Student ID: 2407726

# %% [markdown]
# In this notebook, I have added few more convolution layers to the base model to observe change in performance.

# %% [markdown]
# # **Import Libraries**

# %%
import os, kagglehub, shutil, random
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #**Dataset Curation**

# %%
# Extract dataset from kaggle to colab
src = kagglehub.dataset_download("abdallahalidev/plantvillage-dataset")
# Out:
# Using Colab cache for faster access to the 'plantvillage-dataset' dataset.

# %%
# Move the dataset to /content for faster access
dst = '/content/plant'
if not os.path.exists(dst):
    shutil.copytree(os.path.join(src, 'plantvillage dataset/color'), dst)
else:
    print("Destination already exists. Skipping copy.")

# %%
# Check dataset structure
classes = os.listdir(dst)
print("Total classes:", len(classes))
print(classes[:10])
# Out:
# Total classes: 38
# ['Tomato___Bacterial_spot', 'Tomato___Tomato_mosaic_virus', 'Potato___Late_blight', 'Cherry_(including_sour)___Powdery_mildew', 'Corn_(maize)___Common_rust_', 'Apple___Apple_scab', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Orange___Haunglongbing_(Citrus_greening)', 'Potato___healthy', 'Pepper,_bell___Bacterial_spot']

# %%
# Set paths for train, validation and test sets
train_dir = Path("/content/data/train")
val_dir   = Path("/content/data/val")
test_dir  = Path("/content/data/test")

for d in [train_dir, val_dir, test_dir]:
    d.mkdir(parents=True, exist_ok=True)

# %%
# Function to split data into train, test and validation sets randomly
def split_data(src_dir, train_dir, val_dir, test_dir, split=(0.7, 0.15, 0.15)):
    for cls in os.listdir(src_dir):
        images = os.listdir(os.path.join(src_dir, cls))
        random.shuffle(images)

        n = len(images)
        train_split = int(split[0] * n)
        val_split   = int(split[1] * n)

        train_imgs = images[:train_split]
        val_imgs   = images[train_split:train_split+val_split]
        test_imgs  = images[train_split+val_split:]

        for folder, img_list in zip(
            [train_dir, val_dir, test_dir],
            [train_imgs, val_imgs, test_imgs]
        ):
            cls_path = folder / cls
            cls_path.mkdir(parents=True, exist_ok=True)

            for img in img_list:
                src = os.path.join(src_dir, cls, img)
                dst = cls_path / img
                shutil.copy(src, dst)

# %%
# Call split function
split_data('/content/plant', train_dir, val_dir, test_dir)

# %%
# Count the number of images per split
def count_images(directory):
    counts = {}
    for cls in os.listdir(directory):
        counts[cls] = len(os.listdir(os.path.join(directory, cls)))
    return counts

print("Train:", count_images(train_dir))
print("Val:", count_images(val_dir))
print("Test:", count_images(test_dir))
# Out:
# Train: {'Tomato___Bacterial_spot': 1488, 'Tomato___Tomato_mosaic_virus': 261, 'Potato___Late_blight': 700, 'Cherry_(including_sour)___Powdery_mildew': 736, 'Corn_(maize)___Common_rust_': 834, 'Apple___Apple_scab': 441, 'Tomato___Spider_mites Two-spotted_spider_mite': 1173, 'Orange___Haunglongbing_(Citrus_greening)': 3854, 'Potato___healthy': 106, 'Pepper,_bell___Bacterial_spot': 697, 'Peach___healthy': 251, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus':
 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 78, 'Cherry_(including_sour)___healthy': 129, 'Apple___Cedar_apple_rust': 42, 'Corn_(maize)___healthy': 175, 'Blueberry___healthy': 226, 'Grape___healthy': 64, 'Grape___Black_rot': 177, 'Strawberry___healthy': 69, 'Potato___Early_blight': 150, 'Peach___Bacterial_spot': 346, 'Squash___Powdery_mildew': 276, 'Tomato___Late_blight': 287, 'Grape___Esca_(Black_Measles)': 208, 'Raspberry___healthy': 57, 'Tomato___Target_Spot': 212, 'Tomato___Early_blight': 150, 'Tomato___Septoria_leaf_spot': 267, 'Soybean___healthy': 764}

# %%
# Visualize class distribution
counts = count_images(train_dir)

plt.bar(counts.keys(), counts.values())
plt.xticks(rotation=90)
plt.title("Training Class Distribution")
plt.show()

# %%
# Visualize some images
sample_class = list(counts.keys())[0]
sample_images = os.listdir(train_dir / sample_class)[:5]

plt.figure(figsize=(10,5))

for i, img_name in enumerate(sample_images):
    img = Image.open(train_dir / sample_class / img_name)
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %% [markdown]
# # **Data Pipeline**

# %%
# Load data using tensorflow

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 37997 files belonging to 38 classes.
# Found 8129 files belonging to 38 classes.
# Found 8179 files belonging to 38 classes.

# %%
# Extract class names

class_names = train_ds.class_names
num_classes = len(class_names)

print(num_classes)
print(class_names[:5])
# Out:
# 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy']

# %%
# Normalize the data

normalization_layer = layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds  = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ## Data Agumentation

# %%
# Define steps to be used to Augment data

data_augmentation = Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

# %%
# Augment only the train set

def augment(x, y):
    return data_augmentation(x, training=True), y

train_ds = train_ds.map(augment)

# %%
# Visualize agumented Data
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))

    for i in range(9):
        # original
        ax = plt.subplot(3, 6, 2*i + 1)
        plt.imshow(images[i].numpy())
        plt.title("Original")
        plt.axis("off")

        # augmented
        augmented = data_augmentation(images[i:i+1])[0]
        ax = plt.subplot(3, 6, 2*i + 2)
        plt.imshow(augmented.numpy())
        plt.title("Augmented")
        plt.axis("off")

plt.show()

# %%
# Check image shape to ensure correct image loading + normalization

for images, labels in train_ds.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
# Out:
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)

# %% [markdown]
# # **Deep Model**

# %%
# Build the model architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    # New
    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    # New
    Conv2D(512, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    GlobalAveragePooling2D(),

    # Dense layers
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

# %%
# Compile model
optimizer = Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Define callbacks
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor='val_loss',
    save_best_only=True
)

# %%
# Compute weights to be assigned to each class
y_train = []

for images, labels in train_ds:
    y_train.extend(labels.numpy())

y_train = np.array(y_train)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weights = dict(enumerate(class_weights))

print(class_weights)
# Out:
# {0: np.float64(2.267394677169113), 1: np.float64(2.3039655590589376), 2: np.float64(5.207922149122807), 3: np.float64(0.8687411404270886), 4: np.float64(0.9513996694877059), 5: np.float64(1.358588386727689), 6: np.float64(1.6749096358987923), 7: np.float64(2.7852954112300248), 8: np.float64(1.1989461062728763), 9: np.float64(1.4512642273317546), 10: np.float64(1.229915193888781), 11: np.float64(1.210558175098764), 12: np.float64(1.0329762940408873), 13: np.float64(1.3279164045572098), 14: np.float64(3.378111664295875), 15: np.float64(0.2594501952858274), 16: np.float64(0.6222284086070808), 17: np.float64(3.9837492136716293), 18: np.float64(1.434606962168693), 19: np.float64(0.9670416369744477), 20: np.float64(1.4284586466165414), 21: np.float64(1.4284586466165414), 22: np.float64(9.433217477656406), 23: np.float64(3.860699044909571), 24: np.float64(0.2806402056221103), 25: np.float64(0.7787547138875226), 26: np.float64(1.2885580575149214), 27: np.float64(3.1345487543309685), 28: np.float64(0.6719899547255235), 29: np.float64(1.4284586466165414), 30: np.float64(0.7484439016703435), 31: np.float64(1.5013829619092778), 32: np.float64(0.8070387833991759), 33: np.float64(0.8524476152016871), 34: np.float64(1.018249544431343), 35: np.float64(0.2667167384986874), 36: np.float64(3.8311151441822946), 37: np.float64(0.8984016645387053)}

# %%
start = time.time()

# Train
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[early_stop, reduce_lr, checkpoint],
    class_weight=class_weights
)

end = time.time()
print("Training Time:", end - start)
# Out:
# Epoch 1/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 588s 481ms/step - accuracy: 0.3634 - loss: 2.4087 - val_accuracy: 0.5530 - val_loss: 1.6339 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 463ms/step - accuracy: 0.5870 - loss: 1.4421 - val_accuracy: 0.6605 - val_loss: 1.1127 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 550s 462ms/step - accuracy: 0.7006 - loss: 1.0141 - val_accuracy: 0.7118 - val_loss: 0.9841 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 463ms/step - accuracy: 0.7721 - loss: 0.7493 - val_accuracy: 0.7532 - val_loss: 0.8379 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 552s 464ms/step - accuracy: 0.8157 - loss: 0.6003 - val_accuracy: 0.7729 - val_loss: 0.8402 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 554s 466ms/step - accuracy: 0.8463 - loss: 0.4841 - val_accuracy: 0.7059 - val_loss: 1.1446 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 463ms/step - accuracy: 0.8710 - loss: 0.4040 - val_accuracy: 0.8361 - val_loss: 0.6160 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 552s 465ms/step - accuracy: 0.8866 - loss: 0.3496 - val_accuracy: 0.8427 - val_loss: 0.5685 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 562s 473ms/step - accuracy: 0.9000 - loss: 0.3116 - val_accuracy: 0.8605 - val_loss: 0.4752 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 549s 462ms/step - accuracy: 0.9084 - loss: 0.2881 - val_accuracy: 0.7470 - val_loss: 0.9051 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 464ms/step - accuracy: 0.9215 - loss: 0.2406 - val_accuracy: 0.8984 - val_loss: 0.3665 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 554s 466ms/step - accuracy: 0.9282 - loss: 0.2209 - val_accuracy: 0.8181 - val_loss: 0.7145 - learning_rate: 1.0000e-04
# Epoch 13/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 547s 460ms/step - accuracy: 0.9351 - loss: 0.1950 - val_accuracy: 0.8867 - val_loss: 0.4063 - learning_rate: 1.0000e-04
# Epoch 14/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 546s 460ms/step - accuracy: 0.9400 - loss: 0.1788 - val_accuracy: 0.9247 - val_loss: 0.2551 - learning_rate: 1.0000e-04
# Epoch 15/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 464ms/step - accuracy: 0.9422 - loss: 0.1671 - val_accuracy: 0.8681 - val_loss: 0.4941 - learning_rate: 1.0000e-04
# Epoch 16/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 552s 465ms/step - accuracy: 0.9450 - loss: 0.1630 - val_accuracy: 0.8929 - val_loss: 0.4153 - learning_rate: 1.0000e-04
# Epoch 17/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 558s 469ms/step - accuracy: 0.9504 - loss: 0.1473 - val_accuracy: 0.9111 - val_loss: 0.2946 - learning_rate: 1.0000e-04
# Epoch 18/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 550s 463ms/step - accuracy: 0.9646 - loss: 0.1067 - val_accuracy: 0.9328 - val_loss: 0.2509 - learning_rate: 3.0000e-05
# Epoch 19/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 551s 463ms/step - accuracy: 0.9710 - loss: 0.0871 - val_accuracy: 0.9459 - val_loss: 0.1971 - learning_rate: 3.0000e-05
# Epoch 20/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 554s 467ms/step - accuracy: 0.9734 - loss: 0.0789 - val_accuracy: 0.9362 - val_loss: 0.2194 - learning_rate: 3.0000e-05
# Training Time: 11074.06230378151

# %%
# Save the model
model.save("deep_model.keras")

# %% [markdown]
# # **Evaluation**

# %%
# Get predictions for test set

y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Get metrics for evaluation of the model
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.96      0.96      0.96        95
#                                  Apple___Black_rot       0.87      0.98      0.92        94
#                           Apple___Cedar_apple_rust       0.98      1.00      0.99        42
#                                    Apple___healthy       0.88      0.99      0.93       248
#                                Blueberry___healthy       0.99      0.91      0.95       226
#           Cherry_(including_sour)___Powdery_mildew       0.99      0.96      0.97       159
#                  Cherry_(including_sour)___healthy       0.98      0.99      0.98       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.80      1.00      0.89        78
#                        Corn_(maize)___Common_rust_       0.99      0.99      0.99       180
#                Corn_(maize)___Northern_Leaf_Blight       1.00      0.88      0.94       149
#                             Corn_(maize)___healthy       0.99      1.00      0.99       175
#                                  Grape___Black_rot       0.99      0.97      0.98       177
#                       Grape___Esca_(Black_Measles)       0.99      1.00      1.00       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.86      1.00      0.93       162
#                                    Grape___healthy       0.84      1.00      0.91        64
#           Orange___Haunglongbing_(Citrus_greening)       0.99      1.00      1.00       827
#                             Peach___Bacterial_spot       1.00      0.95      0.97       346
#                                    Peach___healthy       0.98      0.85      0.91        55
#                      Pepper,_bell___Bacterial_spot       0.98      0.94      0.96       151
#                             Pepper,_bell___healthy       0.96      0.96      0.96       223
#                              Potato___Early_blight       0.78      1.00      0.87       150
#                               Potato___Late_blight       0.91      0.94      0.92       150
#                                   Potato___healthy       0.93      0.58      0.72        24
#                                Raspberry___healthy       0.93      0.98      0.96        57
#                                  Soybean___healthy       0.93      0.99      0.96       764
#                            Squash___Powdery_mildew       0.99      1.00      0.99       276
#                           Strawberry___Leaf_scorch       1.00      0.99      1.00       167
#                               Strawberry___healthy       0.81      1.00      0.90        69
#                            Tomato___Bacterial_spot       0.95      0.97      0.96       320
#                              Tomato___Early_blight       0.99      0.69      0.82       150
#                               Tomato___Late_blight       0.96      0.89      0.92       287
#                                 Tomato___Leaf_Mold       1.00      0.93      0.96       144
#                        Tomato___Septoria_leaf_spot       1.00      0.90      0.95       267
#      Tomato___Spider_mites Two-spotted_spider_mite       0.92      0.63      0.75       252
#                               Tomato___Target_Spot       0.93      0.66      0.77       212
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      0.96      0.98       805
#                       Tomato___Tomato_mosaic_virus       1.00      0.91      0.95        57
#                                   Tomato___healthy       0.65      1.00      0.79       240
#
#                                           accuracy                           0.94      8179
#                                          macro avg       0.94      0.93      0.93      8179
#                                       weighted avg       0.95      0.94      0.94      8179

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Track how accuracy and loss changed across training
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.show()
