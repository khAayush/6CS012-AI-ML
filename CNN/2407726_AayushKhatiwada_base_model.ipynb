# %% [markdown]
# ### **Image Classification using Baseline CNN Model From Scratch**
# - Prepared By: **Aayush Khatiwada**
# - L6CG13 | Student ID: 2407726

# %% [markdown]
# In this notebook, I have designed a Baseline CNN model that classifies the diseased plants using the PlantVillage Dataset. Source:https://www.kaggle.com/datasets/abdallahalidev/plantvillage-dataset/data

# %% [markdown]
# # **Import Libraries**

# %%
import os, kagglehub, shutil, random
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #**Dataset Curation**

# %%
# Extract dataset from kaggle to colab
src = kagglehub.dataset_download("abdallahalidev/plantvillage-dataset")
# Out:
# Using Colab cache for faster access to the 'plantvillage-dataset' dataset.

# %%
# Move the dataset to /content for faster access
dst = '/content/plant'
if not os.path.exists(dst):
    shutil.copytree(Path(src, 'plantvillage dataset/color'), dst)
else:
    print("Destination already exists. Skipping copy.")

# %%
# Check dataset structure
classes = os.listdir(dst)
print("Total classes:", len(classes))
print(classes[:10])
# Out:
# Total classes: 38
# ['Apple___healthy', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Potato___Late_blight', 'Tomato___Target_Spot', 'Grape___Black_rot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Tomato___Leaf_Mold', 'Tomato___Bacterial_spot', 'Pepper,_bell___healthy']

# %%
# Set paths for train, validation and test sets
train_dir = Path("/content/data/train")
val_dir   = Path("/content/data/val")
test_dir  = Path("/content/data/test")

for d in [train_dir, val_dir, test_dir]:
    d.mkdir(parents=True, exist_ok=True)

# %%
# Function to split data into train, test and validation sets randomly
def split_data(src_dir, train_dir, val_dir, test_dir, split=(0.7, 0.15, 0.15)):
    for cls in os.listdir(src_dir):
        images = os.listdir(os.path.join(src_dir, cls))
        random.shuffle(images)

        n = len(images)
        train_split = int(split[0] * n)
        val_split   = int(split[1] * n)

        train_imgs = images[:train_split]
        val_imgs   = images[train_split:train_split+val_split]
        test_imgs  = images[train_split+val_split:]

        for folder, img_list in zip(
            [train_dir, val_dir, test_dir],
            [train_imgs, val_imgs, test_imgs]
        ):
            cls_path = folder / cls
            cls_path.mkdir(parents=True, exist_ok=True)

            for img in img_list:
                src = os.path.join(src_dir, cls, img)
                dst = cls_path / img
                shutil.copy(src, dst)

# %%
# Call split function
split_data('/content/plant', train_dir, val_dir, test_dir)

# %%
# Count the number of images per split
def count_images(directory):
    counts = {}
    for cls in os.listdir(directory):
        counts[cls] = len(os.listdir(os.path.join(directory, cls)))
    return counts

print("Train:", count_images(train_dir))
print("Val:", count_images(val_dir))
print("Test:", count_images(test_dir))
# Out:
# Train: {'Apple___healthy': 1151, 'Tomato___Spider_mites Two-spotted_spider_mite': 1173, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 3749, 'Potato___Late_blight': 700, 'Tomato___Target_Spot': 982, 'Grape___Black_rot': 826, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 359, 'Tomato___Leaf_Mold': 666, 'Tomato___Bacterial_spot': 1488, 'Pepper,_bell___healthy': 1034, 'Tomato___healthy': 1113, 'Blueberry___healthy': 1051, 'Peach___Bacterial_spot': 1607, 'Apple___Black_rot': 434, 'Corn_(maize)___healthy': 813, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)':
healthy': 69, 'Apple___Cedar_apple_rust': 42, 'Raspberry___healthy': 57, 'Tomato___Late_blight': 287, 'Orange___Haunglongbing_(Citrus_greening)': 827, 'Grape___Esca_(Black_Measles)': 208, 'Corn_(maize)___Northern_Leaf_Blight': 149, 'Squash___Powdery_mildew': 276, 'Tomato___Septoria_leaf_spot': 267, 'Corn_(maize)___Common_rust_': 180, 'Tomato___Early_blight': 150}

# %%
# Visualize class distribution
counts = count_images(train_dir)

plt.bar(counts.keys(), counts.values())
plt.xticks(rotation=90)
plt.title("Training Class Distribution")
plt.show()

# %%
# Visualize some images
sample_class = list(counts.keys())[0]
sample_images = os.listdir(train_dir / sample_class)[:5]

plt.figure(figsize=(10,5))

for i, img_name in enumerate(sample_images):
    img = Image.open(train_dir / sample_class / img_name)
    plt.subplot(1,5,i+1)
    plt.title(img_name, fontsize=8)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %% [markdown]
# # **Data Pipeline**

# %%
# Load data using tensorflow

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 37997 files belonging to 38 classes.
# Found 8129 files belonging to 38 classes.
# Found 8179 files belonging to 38 classes.

# %%
# Extract class names

class_names = train_ds.class_names
num_classes = len(class_names)

print(num_classes)
print(class_names[:5])
# Out:
# 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy']

# %%
# Normalize the data

normalization_layer = layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds  = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ## Data Agumentation

# %%
# Define steps to be used to Augment data

data_augmentation = Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

# %%
# Augment only the train set

def augment(x, y):
    return data_augmentation(x, training=True), y

train_ds = train_ds.map(augment)

# %%
# Visualize agumented Data
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))

    for i in range(9):
        # original
        ax = plt.subplot(3, 6, 2*i + 1)
        plt.imshow(images[i].numpy())
        plt.title("Original")
        plt.axis("off")

        # augmented
        augmented = data_augmentation(images[i:i+1])[0]
        ax = plt.subplot(3, 6, 2*i + 2)
        plt.imshow(augmented.numpy())
        plt.title("Augmented")
        plt.axis("off")

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0035483].

# %%
# Check image shape to ensure correct image loading + normalization

for images, labels in train_ds.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
# Out:
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)

# %% [markdown]
# # **Baseline Model**

# %%
# Build the model architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    Flatten(),

    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# %%
# Compile model
optimizer = Adam(learning_rate=1e-3)
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Define callbacks
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor='val_loss',
    save_best_only=True
)

# %%
# Compute weights to be assigned to each class
y_train = []

for images, labels in train_ds:
    y_train.extend(labels.numpy())

y_train = np.array(y_train)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weights = dict(enumerate(class_weights))

print(class_weights)
# Out:
# {0: np.float64(2.267394677169113), 1: np.float64(2.3039655590589376), 2: np.float64(5.207922149122807), 3: np.float64(0.8687411404270886), 4: np.float64(0.9513996694877059), 5: np.float64(1.358588386727689), 6: np.float64(1.6749096358987923), 7: np.float64(2.7852954112300248), 8: np.float64(1.1989461062728763), 9: np.float64(1.4512642273317546), 10: np.float64(1.229915193888781), 11: np.float64(1.210558175098764), 12: np.float64(1.0329762940408873), 13: np.float64(1.3279164045572098), 14: np.float64(3.378111664295875), 15: np.float64(0.2594501952858274), 16: np.float64(0.6222284086070808), 17: np.float64(3.9837492136716293), 18: np.float64(1.434606962168693), 19: np.float64(0.9670416369744477), 20: np.float64(1.4284586466165414), 21: np.float64(1.4284586466165414), 22: np.float64(9.433217477656406), 23: np.float64(3.860699044909571), 24: np.float64(0.2806402056221103), 25: np.float64(0.7787547138875226), 26: np.float64(1.2885580575149214), 27: np.float64(3.1345487543309685), 28: np.float64(0.6719899547255235), 29: np.float64(1.4284586466165414), 30: np.float64(0.7484439016703435), 31: np.float64(1.5013829619092778), 32: np.float64(0.8070387833991759), 33: np.float64(0.8524476152016871), 34: np.float64(1.018249544431343), 35: np.float64(0.2667167384986874), 36: np.float64(3.8311151441822946), 37: np.float64(0.8984016645387053)}

# %%
# Train
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[early_stop, reduce_lr, checkpoint],
    class_weight=class_weights
)
# Out:
# Epoch 1/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 545s 448ms/step - accuracy: 0.1583 - loss: 3.3589 - val_accuracy: 0.1596 - val_loss: 5.5899 - learning_rate: 0.0010
# Epoch 2/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 526s 442ms/step - accuracy: 0.3087 - loss: 2.5982 - val_accuracy: 0.1930 - val_loss: 6.1679 - learning_rate: 0.0010
# Epoch 3/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 525s 442ms/step - accuracy: 0.4040 - loss: 2.1372 - val_accuracy: 0.4634 - val_loss: 2.0005 - learning_rate: 0.0010
# Epoch 4/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 524s 441ms/step - accuracy: 0.4820 - loss: 1.7235 - val_accuracy: 0.2669 - val_loss: 4.5365 - learning_rate: 0.0010
# Epoch 5/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 525s 442ms/step - accuracy: 0.6053 - loss: 1.3343 - val_accuracy: 0.3232 - val_loss: 3.1166 - learning_rate: 0.0010
# Epoch 6/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 555s 436ms/step - accuracy: 0.6808 - loss: 1.0487 - val_accuracy: 0.3164 - val_loss: 3.8466 - learning_rate: 0.0010
# Epoch 7/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 528s 445ms/step - accuracy: 0.7695 - loss: 0.7058 - val_accuracy: 0.6490 - val_loss: 1.2744 - learning_rate: 3.0000e-04
# Epoch 8/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 518s 435ms/step - accuracy: 0.7993 - loss: 0.6029 - val_accuracy: 0.7241 - val_loss: 0.9397 - learning_rate: 3.0000e-04
# Epoch 9/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 518s 436ms/step - accuracy: 0.8213 - loss: 0.5318 - val_accuracy: 0.7534 - val_loss: 0.8651 - learning_rate: 3.0000e-04
# Epoch 10/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 522s 439ms/step - accuracy: 0.8436 - loss: 0.4778 - val_accuracy: 0.7477 - val_loss: 1.0087 - learning_rate: 3.0000e-04
# Epoch 11/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 516s 434ms/step - accuracy: 0.8597 - loss: 0.4182 - val_accuracy: 0.7679 - val_loss: 0.9664 - learning_rate: 3.0000e-04
# Epoch 12/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 526s 442ms/step - accuracy: 0.8720 - loss: 0.3812 - val_accuracy: 0.7338 - val_loss: 1.1007 - learning_rate: 3.0000e-04
# Epoch 13/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 520s 437ms/step - accuracy: 0.8972 - loss: 0.3005 - val_accuracy: 0.8257 - val_loss: 0.6354 - learning_rate: 9.0000e-05
# Epoch 14/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 520s 437ms/step - accuracy: 0.9024 - loss: 0.2881 - val_accuracy: 0.7971 - val_loss: 0.8195 - learning_rate: 9.0000e-05
# Epoch 15/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 517s 435ms/step - accuracy: 0.9076 - loss: 0.2731 - val_accuracy: 0.8342 - val_loss: 0.6354 - learning_rate: 9.0000e-05
# Epoch 16/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 515s 434ms/step - accuracy: 0.9117 - loss: 0.2589 - val_accuracy: 0.8364 - val_loss: 0.6390 - learning_rate: 9.0000e-05
# Epoch 17/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 519s 437ms/step - accuracy: 0.9176 - loss: 0.2384 - val_accuracy: 0.8130 - val_loss: 0.7421 - learning_rate: 2.7000e-05
# Epoch 18/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 523s 440ms/step - accuracy: 0.9197 - loss: 0.2284 - val_accuracy: 0.8227 - val_loss: 0.6967 - learning_rate: 2.7000e-05

# %%
# Save the model
model.save("base_model.keras")

# %% [markdown]
# # **Evaluation**

# %%
# Get predictions for test set

y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
# Get metrics for evaluation of the model
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.54      0.92      0.68        95
#                                  Apple___Black_rot       0.74      0.85      0.79        94
#                           Apple___Cedar_apple_rust       0.78      1.00      0.88        42
#                                    Apple___healthy       0.69      0.97      0.81       248
#                                Blueberry___healthy       0.99      0.83      0.90       226
#           Cherry_(including_sour)___Powdery_mildew       0.95      0.93      0.94       159
#                  Cherry_(including_sour)___healthy       0.92      0.94      0.93       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.79      0.79      0.79        78
#                        Corn_(maize)___Common_rust_       0.97      1.00      0.99       180
#                Corn_(maize)___Northern_Leaf_Blight       0.90      0.87      0.89       149
#                             Corn_(maize)___healthy       1.00      1.00      1.00       175
#                                  Grape___Black_rot       0.71      0.84      0.77       177
#                       Grape___Esca_(Black_Measles)       0.82      0.91      0.86       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.76      1.00      0.86       162
#                                    Grape___healthy       0.64      0.98      0.78        64
#           Orange___Haunglongbing_(Citrus_greening)       0.99      0.95      0.97       827
#                             Peach___Bacterial_spot       0.93      0.70      0.80       346
#                                    Peach___healthy       0.93      0.76      0.84        55
#                      Pepper,_bell___Bacterial_spot       0.80      0.38      0.51       151
#                             Pepper,_bell___healthy       0.88      0.85      0.86       223
#                              Potato___Early_blight       0.58      0.99      0.73       150
#                               Potato___Late_blight       0.60      0.85      0.70       150
#                                   Potato___healthy       0.22      0.42      0.29        24
#                                Raspberry___healthy       0.43      0.95      0.59        57
#                                  Soybean___healthy       0.99      0.94      0.96       764
#                            Squash___Powdery_mildew       0.97      0.99      0.98       276
#                           Strawberry___Leaf_scorch       0.89      0.98      0.93       167
#                               Strawberry___healthy       0.51      1.00      0.67        69
#                            Tomato___Bacterial_spot       0.77      0.88      0.82       320
#                              Tomato___Early_blight       0.65      0.53      0.59       150
#                               Tomato___Late_blight       0.96      0.54      0.69       287
#                                 Tomato___Leaf_Mold       0.95      0.69      0.80       144
#                        Tomato___Septoria_leaf_spot       0.80      0.57      0.67       267
#      Tomato___Spider_mites Two-spotted_spider_mite       0.64      0.47      0.54       252
#                               Tomato___Target_Spot       0.51      0.59      0.55       212
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.98      0.79      0.87       805
#                       Tomato___Tomato_mosaic_virus       0.97      0.53      0.68        57
#                                   Tomato___healthy       0.72      0.88      0.79       240
#
#                                           accuracy                           0.83      8179
#                                          macro avg       0.79      0.82      0.78      8179
#                                       weighted avg       0.86      0.83      0.83      8179

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Track how accuracy and loss changed across training
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.show()
