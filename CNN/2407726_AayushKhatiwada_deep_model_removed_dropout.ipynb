# %% [markdown]
# ### **Image Classification using Deep CNN Model(Removed Dropout)**
# - Prepared By: **Aayush Khatiwada**
# - L6CG13 | Student ID: 2407726

# %% [markdown]
# In this notebook, I have removed the dropout component in deep model to observe change in performance.

# %% [markdown]
# # **Import Libraries**

# %%
import os, kagglehub, shutil, random
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #**Dataset Curation**

# %%
# Extract dataset from kaggle to colab
src = kagglehub.dataset_download("abdallahalidev/plantvillage-dataset")
# Out:
# Using Colab cache for faster access to the 'plantvillage-dataset' dataset.

# %%
# Move the dataset to /content for faster access
dst = '/content/plant'
if not os.path.exists(dst):
    shutil.copytree(os.path.join(src, 'plantvillage dataset/color'), dst)
else:
    print("Destination already exists. Skipping copy.")

# %%
# Check dataset structure
classes = os.listdir(dst)
print("Total classes:", len(classes))
print(classes[:10])
# Out:
# Total classes: 38
# ['Apple___healthy', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Potato___Late_blight', 'Tomato___Target_Spot', 'Grape___Black_rot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Tomato___Leaf_Mold', 'Tomato___Bacterial_spot', 'Pepper,_bell___healthy']

# %%
# Set paths for train, validation and test sets
train_dir = Path("/content/data/train")
val_dir   = Path("/content/data/val")
test_dir  = Path("/content/data/test")

for d in [train_dir, val_dir, test_dir]:
    d.mkdir(parents=True, exist_ok=True)

# %%
# Function to split data into train, test and validation sets randomly
def split_data(src_dir, train_dir, val_dir, test_dir, split=(0.7, 0.15, 0.15)):
    for cls in os.listdir(src_dir):
        images = os.listdir(os.path.join(src_dir, cls))
        random.shuffle(images)

        n = len(images)
        train_split = int(split[0] * n)
        val_split   = int(split[1] * n)

        train_imgs = images[:train_split]
        val_imgs   = images[train_split:train_split+val_split]
        test_imgs  = images[train_split+val_split:]

        for folder, img_list in zip(
            [train_dir, val_dir, test_dir],
            [train_imgs, val_imgs, test_imgs]
        ):
            cls_path = folder / cls
            cls_path.mkdir(parents=True, exist_ok=True)

            for img in img_list:
                src = os.path.join(src_dir, cls, img)
                dst = cls_path / img
                shutil.copy(src, dst)

# %%
# Call split function
split_data('/content/plant', train_dir, val_dir, test_dir)

# %%
# Count the number of images per split
def count_images(directory):
    counts = {}
    for cls in os.listdir(directory):
        counts[cls] = len(os.listdir(os.path.join(directory, cls)))
    return counts

print("Train:", count_images(train_dir))
print("Val:", count_images(val_dir))
print("Test:", count_images(test_dir))
# Out:
# Train: {'Apple___healthy': 1151, 'Tomato___Spider_mites Two-spotted_spider_mite': 1173, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 3749, 'Potato___Late_blight': 700, 'Tomato___Target_Spot': 982, 'Grape___Black_rot': 826, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 359, 'Tomato___Leaf_Mold': 666, 'Tomato___Bacterial_spot': 1488, 'Pepper,_bell___healthy': 1034, 'Tomato___healthy': 1113, 'Blueberry___healthy': 1051, 'Peach___Bacterial_spot': 1607, 'Apple___Black_rot': 434, 'Corn_(maize)___healthy': 813, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 753, 'Strawberry___Leaf_scorch': 776, 'Potato___healthy': 106, 'Apple___Apple_scab': 441, 'Grape___healthy': 296, 'Cherry_(including_sour)___Powdery_mildew': 736, 'Peach___healthy': 251, 'Potato___Early_blight': 700, 'Cherry_(including_sour)___healthy': 597, 'Pepper,_bell___Bacterial_spot': 697, 'Soybean___healthy': 3563, 'Tomato___Tomato_mosaic_virus': 261, 'Strawberry___healthy': 319, 'Apple___Cedar_apple_rust': 192, 'Raspberry___healthy': 259, 'Tomato___Late_blight': 1336, 'Orange___Haunglongbing_(Citrus_greening)': 3854, 'Grape___Esca_(Black_Measles)': 968, 'Corn_(maize)___Northern_Leaf_Blight': 689, 'Squash___Powdery_mildew': 1284, 'Tomato___Septoria_leaf_spot': 1239, 'Corn_(maize)___Common_rust_': 834, 'Tomato___Early_blight': 700}
# Val: {'Apple___healthy': 246, 'Tomato___Spider_mites Two-spotted_spider_mite': 251, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 803, 'Potato___Late_blight': 150, 'Tomato___Target_Spot': 210, 'Grape___Black_rot': 177, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 76, 'Tomato___Leaf_Mold': 142, 'Tomato___Bacterial_spot': 319, 'Pepper,_bell___healthy': 221, 'Tomato___healthy': 238, 'Blueberry___healthy': 225, 'Peach___Bacterial_spot': 344, 'Apple___Black_rot': 93, 'Corn_(maize)___healthy': 174, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 161, 'Strawberry___Leaf_scorch': 166, 'Potato___healthy': 22, 'Apple___Apple_scab': 94, 'Grape___healthy': 63, 'Cherry_(including_sour)___Powdery_mildew': 157, 'Peach___healthy': 54, 'Potato___Early_blight': 150, 'Cherry_(including_sour)___healthy': 128, 'Pepper,_bell___Bacterial_spot': 149, 'Soybean___healthy': 763, 'Tomato___Tomato_mosaic_virus': 55, 'Strawberry___healthy': 68, 'Apple___Cedar_apple_rust': 41, 'Raspberry___healthy': 55, 'Tomato___Late_blight': 286, 'Orange___Haunglongbing_(Citrus_greening)': 826, 'Grape___Esca_(Black_Measles)': 207, 'Corn_(maize)___Northern_Leaf_Blight': 147, 'Squash___Powdery_mildew': 275, 'Tomato___Septoria_leaf_spot': 265, 'Corn_(maize)___Common_rust_': 178, 'Tomato___Early_blight': 150}
# Test: {'Apple___healthy': 248, 'Tomato___Spider_mites Two-spotted_spider_mite': 252, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 805, 'Potato___Late_blight': 150, 'Tomato___Target_Spot': 212, 'Grape___Black_rot': 177, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 78, 'Tomato___Leaf_Mold': 144, 'Tomato___Bacterial_spot': 320, 'Pepper,_bell___healthy': 223, 'Tomato___healthy': 240, 'Blueberry___healthy': 226, 'Peach___Bacterial_spot': 346, 'Apple___Black_rot': 94, 'Corn_(maize)___healthy': 175, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 162, 'Strawberry___Leaf_scorch': 167, 'Potato___healthy': 24, 'Apple___Apple_scab': 95, 'Grape___healthy': 64, 'Cherry_(including_sour)___Powdery_mildew': 159, 'Peach___healthy': 55, 'Potato___Early_blight': 150, 'Cherry_(including_sour)___healthy': 129, 'Pepper,_bell___Bacterial_spot': 151, 'Soybean___healthy': 764, 'Tomato___Tomato_mosaic_virus': 57, 'Strawberry___healthy': 69, 'Apple___Cedar_apple_rust': 42, 'Raspberry___healthy': 57, 'Tomato___Late_blight': 287, 'Orange___Haunglongbing_(Citrus_greening)': 827, 'Grape___Esca_(Black_Measles)': 208, 'Corn_(maize)___Northern_Leaf_Blight': 149, 'Squash___Powdery_mildew': 276, 'Tomato___Septoria_leaf_spot': 267, 'Corn_(maize)___Common_rust_': 180, 'Tomato___Early_blight': 150}

# %%
# Visualize class distribution
counts = count_images(train_dir)

plt.bar(counts.keys(), counts.values())
plt.xticks(rotation=90)
plt.title("Training Class Distribution")
plt.show()

# %%
# Visualize some images
sample_class = list(counts.keys())[0]
sample_images = os.listdir(train_dir / sample_class)[:5]

plt.figure(figsize=(10,5))

for i, img_name in enumerate(sample_images):
    img = Image.open(train_dir / sample_class / img_name)
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')

plt.show()

# %% [markdown]
# # **Data Pipeline**

# %%
# Load data using tensorflow

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/data/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 37997 files belonging to 38 classes.
# Found 8129 files belonging to 38 classes.
# Found 8179 files belonging to 38 classes.

# %%
# Extract class names

class_names = train_ds.class_names
num_classes = len(class_names)

print(num_classes)
print(class_names[:5])
# Out:
# 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy']

# %%
# Normalize the data

normalization_layer = layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds  = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ## Data Agumentation

# %%
# Define steps to be used to Augment data

data_augmentation = Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

# %%
# Augment only the train set

def augment(x, y):
    return data_augmentation(x, training=True), y

train_ds = train_ds.map(augment)

# %%
# Visualize agumented Data
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))

    for i in range(9):
        # original
        ax = plt.subplot(3, 6, 2*i + 1)
        plt.imshow(images[i].numpy())
        plt.title("Original")
        plt.axis("off")

        # augmented
        augmented = data_augmentation(images[i:i+1])[0]
        ax = plt.subplot(3, 6, 2*i + 2)
        plt.imshow(augmented.numpy())
        plt.title("Augmented")
        plt.axis("off")

plt.show()

# %%
# Check image shape to ensure correct image loading + normalization

for images, labels in train_ds.take(1):
    print("Image batch shape:", images.shape)
    print("Label batch shape:", labels.shape)
# Out:
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)

# %% [markdown]
# # **Deep Model**

# %%
# Build the model architecture
model = Sequential([
    Conv2D(32, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D(),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D(),

    # New
    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D(),

    # New
    Conv2D(512, (3,3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D(),

    GlobalAveragePooling2D(),

    # Dense layers
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# Used global average pooling instead of flatten as it ensures:
# - Drastically fewer parameters
# - Better generalization
# - Less overfitting

# %%
# Compile model
optimizer = Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Define callbacks
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor='val_loss',
    save_best_only=True
)

# %%
# Compute weights to be assigned to each class
y_train = []

for images, labels in train_ds:
    y_train.extend(labels.numpy())

y_train = np.array(y_train)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weights = dict(enumerate(class_weights))

print(class_weights)
# Out:
# {0: np.float64(2.267394677169113), 1: np.float64(2.3039655590589376), 2: np.float64(5.207922149122807), 3: np.float64(0.8687411404270886), 4: np.float64(0.9513996694877059), 5: np.float64(1.358588386727689), 6: np.float64(1.6749096358987923), 7: np.float64(2.7852954112300248), 8: np.float64(1.1989461062728763), 9: np.float64(1.4512642273317546), 10: np.float64(1.229915193888781), 11: np.float64(1.210558175098764), 12: np.float64(1.0329762940408873), 13: np.float64(1.3279164045572098), 14: np.float64(3.378111664295875), 15: np.float64(0.2594501952858274), 16: np.float64(0.6222284086070808), 17: np.float64(3.9837492136716293), 18: np.float64(1.434606962168693), 19: np.float64(0.9670416369744477), 20: np.float64(1.4284586466165414), 21: np.float64(1.4284586466165414), 22: np.float64(9.433217477656406), 23: np.float64(3.860699044909571), 24: np.float64(0.2806402056221103), 25: np.float64(0.7787547138875226), 26: np.float64(1.2885580575149214), 27: np.float64(3.1345487543309685), 28: np.float64(0.6719899547255235), 29: np.float64(1.4284586466165414), 30: np.float64(0.7484439016703435), 31: np.float64(1.5013829619092778), 32: np.float64(0.8070387833991759), 33: np.float64(0.8524476152016871), 34: np.float64(1.018249544431343), 35: np.float64(0.2667167384986874), 36: np.float64(3.8311151441822946), 37: np.float64(0.8984016645387053)}

# %%
start = time.time()

# Train
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[early_stop, reduce_lr, checkpoint],
    class_weight=class_weights
)

end = time.time()
print("Training Time:", end - start)
# Out:
# Epoch 1/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 567s 466ms/step - accuracy: 0.6906 - loss: 1.1260 - val_accuracy: 0.6319 - val_loss: 1.3944 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 545s 459ms/step - accuracy: 0.8667 - loss: 0.4210 - val_accuracy: 0.7698 - val_loss: 0.7532 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 540s 454ms/step - accuracy: 0.9098 - loss: 0.2764 - val_accuracy: 0.6851 - val_loss: 1.2204 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 540s 454ms/step - accuracy: 0.9322 - loss: 0.2016 - val_accuracy: 0.7551 - val_loss: 0.8749 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 533s 449ms/step - accuracy: 0.9438 - loss: 0.1661 - val_accuracy: 0.8557 - val_loss: 0.4307 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 537s 452ms/step - accuracy: 0.9526 - loss: 0.1382 - val_accuracy: 0.9315 - val_loss: 0.2051 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 535s 450ms/step - accuracy: 0.9587 - loss: 0.1181 - val_accuracy: 0.9168 - val_loss: 0.2690 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 563s 451ms/step - accuracy: 0.9633 - loss: 0.1082 - val_accuracy: 0.9063 - val_loss: 0.2948 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 531s 446ms/step - accuracy: 0.9690 - loss: 0.0883 - val_accuracy: 0.8749 - val_loss: 0.3939 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 533s 448ms/step - accuracy: 0.9818 - loss: 0.0491 - val_accuracy: 0.9045 - val_loss: 0.3144 - learning_rate: 3.0000e-05
# Epoch 11/20
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 534s 450ms/step - accuracy: 0.9877 - loss: 0.0371 - val_accuracy: 0.9353 - val_loss: 0.2115 - learning_rate: 3.0000e-05
# Training Time: 5958.464763641357

# %%
# Save the model
model.save("final_model.keras")

# %% [markdown]
# # **Evaluation**

# %%
# Get predictions for test set

y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Get metrics for evaluation of the model
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.93      0.95      0.94        95
#                                  Apple___Black_rot       0.98      1.00      0.99        94
#                           Apple___Cedar_apple_rust       0.98      0.98      0.98        42
#                                    Apple___healthy       0.90      0.94      0.92       248
#                                Blueberry___healthy       0.98      0.86      0.92       226
#           Cherry_(including_sour)___Powdery_mildew       0.95      0.99      0.97       159
#                  Cherry_(including_sour)___healthy       0.98      0.98      0.98       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.83      0.79      0.81        78
#                        Corn_(maize)___Common_rust_       1.00      0.99      0.99       180
#                Corn_(maize)___Northern_Leaf_Blight       0.86      0.95      0.90       149
#                             Corn_(maize)___healthy       1.00      0.94      0.97       175
#                                  Grape___Black_rot       1.00      0.86      0.93       177
#                       Grape___Esca_(Black_Measles)       0.94      0.98      0.96       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.97      0.94      0.96       162
#                                    Grape___healthy       1.00      1.00      1.00        64
#           Orange___Haunglongbing_(Citrus_greening)       1.00      0.97      0.99       827
#                             Peach___Bacterial_spot       1.00      0.97      0.98       346
#                                    Peach___healthy       0.95      0.98      0.96        55
#                      Pepper,_bell___Bacterial_spot       0.93      0.99      0.96       151
#                             Pepper,_bell___healthy       0.95      0.96      0.96       223
#                              Potato___Early_blight       0.78      0.99      0.88       150
#                               Potato___Late_blight       0.61      0.98      0.75       150
#                                   Potato___healthy       0.59      0.92      0.72        24
#                                Raspberry___healthy       0.84      1.00      0.91        57
#                                  Soybean___healthy       0.97      0.96      0.97       764
#                            Squash___Powdery_mildew       0.94      1.00      0.97       276
#                           Strawberry___Leaf_scorch       0.98      0.95      0.96       167
#                               Strawberry___healthy       0.80      1.00      0.89        69
#                            Tomato___Bacterial_spot       0.91      0.98      0.95       320
#                              Tomato___Early_blight       0.88      0.71      0.79       150
#                               Tomato___Late_blight       0.92      0.64      0.76       287
#                                 Tomato___Leaf_Mold       0.98      0.82      0.89       144
#                        Tomato___Septoria_leaf_spot       0.90      0.84      0.87       267
#      Tomato___Spider_mites Two-spotted_spider_mite       0.87      0.62      0.73       252
#                               Tomato___Target_Spot       0.75      0.91      0.82       212
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.99      0.94      0.97       805
#                       Tomato___Tomato_mosaic_virus       0.63      1.00      0.78        57
#                                   Tomato___healthy       0.85      0.97      0.91       240
#
#                                           accuracy                           0.93      8179
#                                          macro avg       0.90      0.93      0.91      8179
#                                       weighted avg       0.93      0.93      0.93      8179

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Track how accuracy and loss changed across training
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.show()
