# %% [markdown]
# # **Artificial Intelligence and Machine Learning: Worksheet 6**
# Prepared by: Aayush Khatiwada
# Group: L6CG13

# %% [markdown]
# # Image Classification with CNN and Transfer Learning

# %% [markdown]
# ## 1. Imports and setup

# %%
import os
import shutil
import zipfile
import random
from pathlib import Path
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image, UnidentifiedImageError

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.utils import image_dataset_from_directory

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# ## 2. Locate and extract the dataset

# %%
possible_data_roots = [
    Path("FruitinAmazon"),
    Path("Week5/FruitinAmazon"),
    Path("../Week5/FruitinAmazon"),
    Path("/content/FruitinAmazon"),
    Path("/mnt/data/FruitinAmazon"),
]

possible_zip_paths = [root.with_suffix(".zip") for root in possible_data_roots]

source_path = None
source_kind = None
for p in possible_data_roots:
    if p.exists():
        source_path = p
        source_kind = "directory"
        break

if source_path is None:
    for p in possible_zip_paths:
        if p.exists():
            source_path = p
            source_kind = "zip"
            break

if source_path is None:
    raise FileNotFoundError(
        "Could not find FruitinAmazon as either a folder or a zip file. "
        "Expected it in the current folder, Week5/FruitinAmazon, ../Week5/FruitinAmazon, or the Colab data folders."
    )

if source_kind == "zip":
    extract_dir = source_path.parent / "FruitinAmazon"

    if extract_dir.exists():
        shutil.rmtree(extract_dir)

    with zipfile.ZipFile(source_path, "r") as zip_ref:
        zip_ref.extractall(extract_dir)

    base_dir = extract_dir / "FruitinAmazon"
else:
    base_dir = source_path
    extract_dir = base_dir

train_dir = base_dir / "train"
test_dir = base_dir / "test"

if not train_dir.exists() or not test_dir.exists():
    raise FileNotFoundError(
        f"Expected train/ and test/ folders were not found under: {base_dir}"
    )

print("Source path:", source_path)
print("Source kind:", source_kind)
print("Base dir:", base_dir)
print("Train dir:", train_dir)
print("Test dir:", test_dir)
# Out:
# Source path: FruitinAmazon
# Source kind: directory
# Base dir: FruitinAmazon
# Train dir: FruitinAmazon\train
# Test dir: FruitinAmazon\test

# %% [markdown]
# ## 3. Verify dataset structure and class names
#
# Before training, we confirm that the dataset is organized into class folders inside the training set. This step helps us verify that the labels are available correctly and that the folder structure is suitable for image classification.

# %%
class_names = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])

if not class_names:
    raise ValueError("No class directories found in the train folder.")

print(f"Found {len(class_names)} classes: {class_names}")
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ## 4. Check for corrupted images
#
# We scan both the training and test folders for unreadable image files. Any corrupted images are removed and reported so they do not interfere with model training or evaluation.

# %%
VALID_EXTENSIONS = (".png", ".jpg", ".jpeg", ".bmp", ".gif", ".webp")

def remove_corrupted_images(root_dir):
    corrupted = []
    checked = 0

    for class_dir in sorted(root_dir.iterdir()):
        if not class_dir.is_dir():
            continue

        for img_path in class_dir.iterdir():
            if not img_path.is_file() or img_path.suffix.lower() not in VALID_EXTENSIONS:
                continue

            checked += 1
            try:
                with Image.open(img_path) as img:
                    img.verify()
            except (IOError, SyntaxError, UnidentifiedImageError):
                corrupted.append(str(img_path))
                try:
                    img_path.unlink()
                except Exception as e:
                    print(f"Could not remove {img_path}: {e}")

    return checked, corrupted

train_checked, train_corrupted = remove_corrupted_images(train_dir)
test_checked, test_corrupted = remove_corrupted_images(test_dir)

print(f"Checked {train_checked} train images and {test_checked} test images.")

all_corrupted = train_corrupted + test_corrupted

if all_corrupted:
    print("\nCorrupted images removed:")
    for img in all_corrupted:
        print(img)
else:
    print("\nNo corrupted images found.")
# Out:
# Checked 90 train images and 30 test images.
#
# No corrupted images found.

# %% [markdown]
# ## 5. Count class distribution
#
# A quick count of images in each class helps us understand whether the dataset is balanced. This is useful because a strong imbalance could make the model favor one class more than the others.

# %%
def count_images_by_class(root_dir):
    counts = {}
    for class_dir in sorted(root_dir.iterdir()):
        if class_dir.is_dir():
            counts[class_dir.name] = sum(
                1 for p in class_dir.iterdir()
                if p.is_file() and p.suffix.lower() in VALID_EXTENSIONS
            )
    return counts

train_counts = count_images_by_class(train_dir)
test_counts = count_images_by_class(test_dir)

print("Train Class Distribution")
print("=" * 45)
print(f"{'Class Name':<20}{'Valid Image Count':>20}")
print("=" * 45)
for cls, count in train_counts.items():
    print(f"{cls:<20}{count:>20}")
print("=" * 45)

print("\nTest Class Distribution")
print("=" * 45)
print(f"{'Class Name':<20}{'Valid Image Count':>20}")
print("=" * 45)
for cls, count in test_counts.items():
    print(f"{cls:<20}{count:>20}")
print("=" * 45)
# Out:
# Train Class Distribution
# =============================================
# Class Name             Valid Image Count
# =============================================
# acai                                  15
# cupuacu                               15
# graviola                              15
# guarana                               15
# pupunha                               15
# tucuma                                15
# =============================================
#
# Test Class Distribution
# =============================================
# Class Name             Valid Image Count
# =============================================
# acai                                   5
# cupuacu                                5
# graviola                               5
# guarana                                5
# pupunha                                5
# tucuma                                 5
# =============================================

# %%
plt.figure(figsize=(10, 4))
plt.bar(train_counts.keys(), train_counts.values())
plt.title("Training Set Class Distribution")
plt.xlabel("Class")
plt.ylabel("Number of images")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Visualize one sample from each class
#
# Showing one random image from every class gives a quick visual sanity check. It helps confirm that the folders were read correctly and gives us a feel for the variation in color, shape, and background across the dataset.

# %%
selected_images = []
selected_labels = []

for class_name in class_names:
    class_path = train_dir / class_name
    images = [
        p for p in class_path.iterdir()
        if p.is_file() and p.suffix.lower() in VALID_EXTENSIONS
    ]
    if images:
        chosen = random.choice(images)
        selected_images.append(chosen)
        selected_labels.append(class_name)

num_classes = len(selected_images)
cols = (num_classes + 1) // 2
rows = 2

fig, axes = plt.subplots(rows, cols, figsize=(14, 7))
axes = np.array(axes).reshape(rows, cols)

for i, ax in enumerate(axes.flat):
    if i < num_classes:
        img = mpimg.imread(selected_images[i])
        ax.imshow(img)
        ax.set_title(selected_labels[i])
        ax.axis("off")
    else:
        ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The dataset contains six fruit classes and appears fairly balanced, so major class imbalance is unlikely. The sample images show clear differences in color, shape, and texture, although some classes may still look visually similar. For that reason, data augmentation should help the model generalize better to new images.

# %% [markdown]
# ## 7. Create datasets for Task 1 (CNN from scratch)
#
# For the first model, we split the training data into training and validation subsets, then load the images with Keras. We use a compact image size of **128 × 128** and a batch size of **16** to keep training efficient while still preserving enough detail for classification.

# %%
IMG_SIZE = (128, 128)
BATCH_SIZE = 16
VAL_SPLIT = 0.2

train_ds = image_dataset_from_directory(
    train_dir,
    validation_split=VAL_SPLIT,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="int",
)

val_ds = image_dataset_from_directory(
    train_dir,
    validation_split=VAL_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="int",
)

test_ds = image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    label_mode="int",
)

cnn_class_names = train_ds.class_names
num_classes = len(cnn_class_names)

print("Class names:", cnn_class_names)
print("Number of classes:", num_classes)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.
# Found 30 files belonging to 6 classes.
# Class names: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']
# Number of classes: 6

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 8. Visualize a sample training batch

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(min(9, len(images))):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(cnn_class_names[int(labels[i])])
        plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Data augmentation
#
# Data augmentation makes the training set more diverse by creating slightly altered versions of the original images. This helps the model become more robust to changes in orientation, position, and appearance, which usually improves generalization.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ],
    name="data_augmentation"
)

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    first_image = images[:1]
    for i in range(9):
        augmented_image = data_augmentation(first_image, training=True)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_image[0].numpy().astype("uint8"))
        plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Build the improved CNN model
#
# This CNN is deeper and more carefully regularized than a basic baseline. It combines data augmentation, rescaling, batch normalization, and dropout so the model can learn useful image features while reducing overfitting.

# %%
def build_improved_cnn(input_shape=(128, 128, 3), num_classes=6):
    model = Sequential([
        layers.Input(shape=input_shape),
        data_augmentation,
        layers.Rescaling(1.0 / 255),

        layers.Conv2D(32, (3, 3), padding="same", activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3, 3), padding="same", activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(128, (3, 3), padding="same", activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(256, (3, 3), padding="same", activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Flatten(),

        layers.Dense(512, activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Dropout(0.5),

        layers.Dense(256, activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Dropout(0.5),

        layers.Dense(128, activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Dropout(0.5),

        layers.Dense(64, activation=None),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Dropout(0.5),

        layers.Dense(num_classes, activation="softmax"),
    ], name="improved_cnn")

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

cnn_model = build_improved_cnn(input_shape=IMG_SIZE + (3,), num_classes=num_classes)
cnn_model.summary()
# Out:
# Model: "improved_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,956,166 (34.17 MB)
#  Trainable params: 8,953,286 (34.15 MB)
#  Non-trainable params: 2,880 (11.25 KB)

# %% [markdown]
# ## 11. Train the improved CNN
#
# The model is trained with early stopping, checkpointing, and learning-rate reduction so that training stays efficient and the best-performing weights are preserved automatically.

# %%
cnn_checkpoint_path = "best_improved_cnn.keras"

cnn_callbacks = [
    EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True),
    ModelCheckpoint(cnn_checkpoint_path, monitor="val_loss", save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, verbose=1)
]

EPOCHS_CNN = 60

history_cnn = cnn_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_CNN,
    callbacks=cnn_callbacks,
    verbose=1
)
# Out:
# Epoch 1/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.3028 - loss: 2.1042WARNING:tensorflow:5 out of the last 138 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x000002C2876CC7C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 504ms/step - accuracy: 0.3056 - loss: 2.0582 - val_accuracy: 0.2222 - val_loss: 1.7855 - learning_rate: 0.0010
# Epoch 2/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 407ms/step - accuracy: 0.2639 - loss: 2.0564 - val_accuracy: 0.1667 - val_loss: 1.7652 - learning_rate: 0.0010
# Epoch 3/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.0972 - loss: 2.3188 - val_accuracy: 0.1111 - val_loss: 1.7881 - learning_rate: 0.0010
# Epoch 4/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.1667 - loss: 2.2949 - val_accuracy: 0.2778 - val_loss: 1.7836 - learning_rate: 0.0010
# Epoch 5/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - accuracy: 0.1389 - loss: 2.3911 - val_accuracy: 0.1667 - val_loss: 1.7734 - learning_rate: 0.0010
# Epoch 6/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.1806 - loss: 2.1970 - val_accuracy: 0.1667 - val_loss: 1.7658 - learning_rate: 0.0010
# Epoch 7/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 387ms/step - accuracy: 0.2222 - loss: 2.1739 - val_accuracy: 0.1667 - val_loss: 1.7556 - learning_rate: 0.0010
# Epoch 8/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 394ms/step - accuracy: 0.3056 - loss: 1.8955 - val_accuracy: 0.1667 - val_loss: 1.7402 - learning_rate: 0.0010
# Epoch 9/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - accuracy: 0.2917 - loss: 1.7793 - val_accuracy: 0.1667 - val_loss: 1.7243 - learning_rate: 0.0010
# Epoch 10/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 387ms/step - accuracy: 0.1667 - loss: 2.1374 - val_accuracy: 0.2222 - val_loss: 1.7168 - learning_rate: 0.0010
# Epoch 11/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.2639 - loss: 1.8965 - val_accuracy: 0.2778 - val_loss: 1.7273 - learning_rate: 0.0010
# Epoch 12/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 304ms/step - accuracy: 0.2361 - loss: 1.8332 - val_accuracy: 0.1667 - val_loss: 1.7437 - learning_rate: 0.0010
# Epoch 13/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - accuracy: 0.3194 - loss: 1.6792 - val_accuracy: 0.1667 - val_loss: 1.7412 - learning_rate: 0.0010
# Epoch 14/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.2500 - loss: 1.9143 - val_accuracy: 0.2222 - val_loss: 1.7282 - learning_rate: 0.0010
# Epoch 15/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 386ms/step - accuracy: 0.2639 - loss: 2.0168 - val_accuracy: 0.2222 - val_loss: 1.7099 - learning_rate: 0.0010
# Epoch 16/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.2639 - loss: 1.8212 - val_accuracy: 0.1667 - val_loss: 1.7249 - learning_rate: 0.0010
# Epoch 17/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.3750 - loss: 1.6598 - val_accuracy: 0.1667 - val_loss: 1.7467 - learning_rate: 0.0010
# Epoch 18/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.2778 - loss: 1.8436 - val_accuracy: 0.1667 - val_loss: 1.7805 - learning_rate: 0.0010
# Epoch 19/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.3333 - loss: 1.6248 - val_accuracy: 0.2222 - val_loss: 1.8504 - learning_rate: 0.0010
# Epoch 20/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.2306 - loss: 1.8835
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.2778 - loss: 1.7554 - val_accuracy: 0.2222 - val_loss: 1.9371 - learning_rate: 0.0010
# Epoch 21/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.3472 - loss: 1.6181 - val_accuracy: 0.2222 - val_loss: 1.9962 - learning_rate: 5.0000e-04
# Epoch 22/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - accuracy: 0.3750 - loss: 1.6111 - val_accuracy: 0.2222 - val_loss: 2.0397 - learning_rate: 5.0000e-04
# Epoch 23/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.2917 - loss: 1.5667 - val_accuracy: 0.1667 - val_loss: 2.0770 - learning_rate: 5.0000e-04
# Epoch 24/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.3611 - loss: 1.5514 - val_accuracy: 0.1667 - val_loss: 2.1221 - learning_rate: 5.0000e-04
# Epoch 25/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.4288 - loss: 1.4758
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.4722 - loss: 1.3791 - val_accuracy: 0.2222 - val_loss: 2.1655 - learning_rate: 5.0000e-04
# Epoch 26/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - accuracy: 0.3750 - loss: 1.4525 - val_accuracy: 0.2222 - val_loss: 2.1781 - learning_rate: 2.5000e-04
# Epoch 27/60
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.5000 - loss: 1.2872 - val_accuracy: 0.2222 - val_loss: 2.1842 - learning_rate: 2.5000e-04

# %% [markdown]
# ## 12. Plot training history for the improved CNN

# %%
def plot_history(history, title_prefix="Model"):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Validation Accuracy")
    plt.title(f"{title_prefix} Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 5))
    plt.plot(epochs_range, hist["loss"], label="Train Loss")
    plt.plot(epochs_range, hist["val_loss"], label="Validation Loss")
    plt.title(f"{title_prefix} Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history_cnn, "Improved CNN")

# %% [markdown]
# ## 13. Evaluate the improved CNN on the test set

# %%
best_cnn_model = load_model(cnn_checkpoint_path)

cnn_test_loss, cnn_test_acc = best_cnn_model.evaluate(test_ds, verbose=1)

print(f"Improved CNN Test Loss: {cnn_test_loss:.4f}")
print(f"Improved CNN Test Accuracy: {cnn_test_acc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2333 - loss: 1.7149
# Improved CNN Test Loss: 1.7149
# Improved CNN Test Accuracy: 0.2333

# %% [markdown]
# ## 14. Save and reload the improved CNN model
#
# The worksheet also asks for saving and loading the trained model.

# %%
cnn_keras_path = "improved_cnn_fruit_model.keras"
best_cnn_model.save(cnn_keras_path)

reloaded_cnn_model = load_model(cnn_keras_path)
reloaded_loss, reloaded_acc = reloaded_cnn_model.evaluate(test_ds, verbose=0)

print("Saved model path:", cnn_keras_path)
print(f"Reloaded model test accuracy: {reloaded_acc:.4f}")
# Out:
# Saved model path: improved_cnn_fruit_model.keras
# Reloaded model test accuracy: 0.2333

# %% [markdown]
# ## 15. Predictions and classification report for the improved CNN

# %%
def get_true_labels(dataset):
    y_true = []
    for _, labels in dataset:
        y_true.extend(labels.numpy())
    return np.array(y_true)

def get_predictions(model, dataset):
    probs = model.predict(dataset, verbose=1)
    preds = np.argmax(probs, axis=1)
    return probs, preds

y_true_test = get_true_labels(test_ds)
cnn_probs, cnn_preds = get_predictions(best_cnn_model, test_ds)

print("Classification Report - Improved CNN")
print(classification_report(y_true_test, cnn_preds, target_names=cnn_class_names))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002C256B0FEC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Classification Report - Improved CNN
#               precision    recall  f1-score   support
#
#         acai       0.00      0.00      0.00         5
#      cupuacu       0.18      1.00      0.30         5
#     graviola       1.00      0.40      0.57         5
#      guarana       0.00      0.00      0.00         5
#      pupunha       0.00      0.00      0.00         5
#       tucuma       0.00      0.00      0.00         5
#
#     accuracy                           0.23        30
#    macro avg       0.20      0.23      0.15        30
# weighted avg       0.20      0.23      0.15        30
# f:\Herald Level 6\AI\Workshop\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# f:\Herald Level 6\AI\Workshop\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# f:\Herald Level 6\AI\Workshop\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
cnn_cm = confusion_matrix(y_true_test, cnn_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cnn_cm, display_labels=cnn_class_names)

fig, ax = plt.subplots(figsize=(7, 7))
disp.plot(ax=ax, xticks_rotation=45, colorbar=False)
plt.title("Improved CNN - Confusion Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 16. Task 2 — Transfer Learning with VGG16
#
# For the second approach, we reuse **VGG16**, a convolutional neural network pretrained on ImageNet. The pretrained base acts as a feature extractor, and we add a small custom classifier on top so the model can adapt to the fruit dataset more efficiently.

# %%
TL_IMG_SIZE = (224, 224)
TL_BATCH_SIZE = 16

train_ds_tl = image_dataset_from_directory(
    train_dir,
    validation_split=VAL_SPLIT,
    subset="training",
    seed=SEED,
    image_size=TL_IMG_SIZE,
    batch_size=TL_BATCH_SIZE,
    label_mode="int",
)

val_ds_tl = image_dataset_from_directory(
    train_dir,
    validation_split=VAL_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=TL_IMG_SIZE,
    batch_size=TL_BATCH_SIZE,
    label_mode="int",
)

test_ds_tl = image_dataset_from_directory(
    test_dir,
    image_size=TL_IMG_SIZE,
    batch_size=TL_BATCH_SIZE,
    shuffle=False,
    label_mode="int",
)

tl_class_names = train_ds_tl.class_names

train_ds_tl = train_ds_tl.prefetch(AUTOTUNE)
val_ds_tl = val_ds_tl.prefetch(AUTOTUNE)
test_ds_tl = test_ds_tl.prefetch(AUTOTUNE)

print("Transfer learning class names:", tl_class_names)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.
# Found 30 files belonging to 6 classes.
# Transfer learning class names: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ### Note
#
# The first time you run VGG16 with `weights="imagenet"`, TensorFlow may download the pretrained weights automatically. If you are online in Colab, this usually happens without any extra setup.

# %%
vgg_data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
    ],
    name="vgg_data_augmentation"
)

base_model = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=TL_IMG_SIZE + (3,)
)

base_model.trainable = False

inputs = keras.Input(shape=TL_IMG_SIZE + (3,))
x = vgg_data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

vgg_model = keras.Model(inputs, outputs, name="vgg16_transfer_learning")

vgg_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

vgg_model.summary()
# Out:
# Model: "vgg16_transfer_learning"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg_data_augmentat… │ (None, 224, 224,  │          0 │ input_layer_8[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 224, 224)  │          0 │ vgg_data_augment… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 224, 224)  │          0 │ vgg_data_augment… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 224, 224)  │          0 │ vgg_data_augment… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_1 (Stack)     │ (None, 224, 224,  │          0 │ get_item_3[0][0], │
# │                     │ 3)                │            │ get_item_4[0][0], │
# │                     │                   │            │ get_item_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 224, 224,  │          0 │ stack_1[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256)       │    131,328 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 256)       │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 6)         │      1,542 │ dropout_17[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,847,558 (56.64 MB)
#  Trainable params: 132,870 (519.02 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## 17. Train the VGG16 transfer learning model

# %%
vgg_checkpoint_path = "best_vgg16_transfer.keras"

vgg_callbacks = [
    EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True),
    ModelCheckpoint(vgg_checkpoint_path, monitor="val_loss", save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4, verbose=1)
]

EPOCHS_VGG = 25

history_vgg = vgg_model.fit(
    train_ds_tl,
    validation_data=val_ds_tl,
    epochs=EPOCHS_VGG,
    callbacks=vgg_callbacks,
    verbose=1
)
# Out:
# Epoch 1/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.1250 - loss: 9.6812 - val_accuracy: 0.5000 - val_loss: 2.4008 - learning_rate: 0.0010
# Epoch 2/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.3889 - loss: 3.4343 - val_accuracy: 0.6667 - val_loss: 1.0745 - learning_rate: 0.0010
# Epoch 3/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.6389 - loss: 1.8242 - val_accuracy: 0.8333 - val_loss: 1.1114 - learning_rate: 0.0010
# Epoch 4/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7639 - loss: 1.0500 - val_accuracy: 0.7778 - val_loss: 1.4428 - learning_rate: 0.0010
# Epoch 5/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7639 - loss: 0.8783 - val_accuracy: 0.8333 - val_loss: 0.8334 - learning_rate: 0.0010
# Epoch 6/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9167 - loss: 0.2726 - val_accuracy: 0.9444 - val_loss: 0.6692 - learning_rate: 0.0010
# Epoch 7/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.8333 - loss: 0.5299 - val_accuracy: 0.8889 - val_loss: 0.5949 - learning_rate: 0.0010
# Epoch 8/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9306 - loss: 0.3420 - val_accuracy: 0.8889 - val_loss: 0.6052 - learning_rate: 0.0010
# Epoch 9/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9167 - loss: 0.3121 - val_accuracy: 0.8333 - val_loss: 0.6158 - learning_rate: 0.0010
# Epoch 10/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8889 - loss: 0.3750 - val_accuracy: 0.8333 - val_loss: 0.6196 - learning_rate: 0.0010
# Epoch 11/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9306 - loss: 0.2085 - val_accuracy: 0.8889 - val_loss: 0.5687 - learning_rate: 0.0010
# Epoch 12/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9583 - loss: 0.0805 - val_accuracy: 0.8889 - val_loss: 0.5878 - learning_rate: 0.0010
# Epoch 13/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9444 - loss: 0.2619 - val_accuracy: 0.8889 - val_loss: 0.6327 - learning_rate: 0.0010
# Epoch 14/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9861 - loss: 0.0397 - val_accuracy: 0.8333 - val_loss: 0.8038 - learning_rate: 0.0010
# Epoch 15/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9882 - loss: 0.0462
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9722 - loss: 0.0941 - val_accuracy: 0.8333 - val_loss: 0.9144 - learning_rate: 0.0010
# Epoch 16/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9722 - loss: 0.1607 - val_accuracy: 0.8333 - val_loss: 0.8867 - learning_rate: 5.0000e-04
# Epoch 17/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9583 - loss: 0.1445 - val_accuracy: 0.8333 - val_loss: 0.8564 - learning_rate: 5.0000e-04
# Epoch 18/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9583 - loss: 0.0972 - val_accuracy: 0.8333 - val_loss: 0.7857 - learning_rate: 5.0000e-04
# Epoch 19/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - accuracy: 0.9392 - loss: 0.2582
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9306 - loss: 0.2907 - val_accuracy: 0.8889 - val_loss: 0.6603 - learning_rate: 5.0000e-04

# %% [markdown]
# ## 18. Plot training history for VGG16 transfer learning

# %%
plot_history(history_vgg, "VGG16 Transfer Learning")

# %% [markdown]
# ## 19. Evaluate the VGG16 transfer learning model

# %%
best_vgg_model = load_model(vgg_checkpoint_path)

vgg_test_loss, vgg_test_acc = best_vgg_model.evaluate(test_ds_tl, verbose=1)

print(f"VGG16 Test Loss: {vgg_test_loss:.4f}")
print(f"VGG16 Test Accuracy: {vgg_test_acc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7333 - loss: 1.1743
# VGG16 Test Loss: 1.1743
# VGG16 Test Accuracy: 0.7333

# %% [markdown]
# ## 20. Save, reload, and evaluate the VGG16 model

# %%
vgg_keras_path = "vgg16_transfer_fruit_model.keras"
best_vgg_model.save(vgg_keras_path)

reloaded_vgg_model = load_model(vgg_keras_path)
reloaded_vgg_loss, reloaded_vgg_acc = reloaded_vgg_model.evaluate(test_ds_tl, verbose=0)

print("Saved model path:", vgg_keras_path)
print(f"Reloaded VGG16 model test accuracy: {reloaded_vgg_acc:.4f}")
# Out:
# Saved model path: vgg16_transfer_fruit_model.keras
# Reloaded VGG16 model test accuracy: 0.7333

# %% [markdown]
# ## 21. Predictions and classification report for VGG16

# %%
y_true_test_tl = get_true_labels(test_ds_tl)
vgg_probs, vgg_preds = get_predictions(best_vgg_model, test_ds_tl)

print("Classification Report - VGG16 Transfer Learning")
print(classification_report(y_true_test_tl, vgg_preds, target_names=tl_class_names))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# Classification Report - VGG16 Transfer Learning
#               precision    recall  f1-score   support
#
#         acai       0.80      0.80      0.80         5
#      cupuacu       1.00      0.40      0.57         5
#     graviola       0.83      1.00      0.91         5
#      guarana       1.00      0.80      0.89         5
#      pupunha       0.67      0.80      0.73         5
#       tucuma       0.43      0.60      0.50         5
#
#     accuracy                           0.73        30
#    macro avg       0.79      0.73      0.73        30
# weighted avg       0.79      0.73      0.73        30

# %%
vgg_cm = confusion_matrix(y_true_test_tl, vgg_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=vgg_cm, display_labels=tl_class_names)

fig, ax = plt.subplots(figsize=(7, 7))
disp.plot(ax=ax, xticks_rotation=45, colorbar=False)
plt.title("VGG16 Transfer Learning - Confusion Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 22. Example inference output
#
# This section shows how the trained model performs on a few test images. Comparing the true label with the predicted label is a simple but effective way to check whether the classifier is making sensible predictions.

# %%
sample_paths = []
sample_true = []

for cls in class_names:
    cls_dir = test_dir / cls
    images = [p for p in cls_dir.iterdir() if p.is_file() and p.suffix.lower() in VALID_EXTENSIONS]
    if images:
        chosen = random.choice(images)
        sample_paths.append(chosen)
        sample_true.append(cls)

def load_and_prepare_image(img_path, image_size, preprocess_fn=None):
    img = keras.utils.load_img(img_path, target_size=image_size)
    arr = keras.utils.img_to_array(img)
    arr = np.expand_dims(arr, axis=0)
    if preprocess_fn is not None:
        arr = preprocess_fn(arr.copy())
    return img, arr

plt.figure(figsize=(14, 8))
for i, (img_path, true_label) in enumerate(zip(sample_paths[:6], sample_true[:6]), start=1):
    img, arr = load_and_prepare_image(img_path, TL_IMG_SIZE, preprocess_input)
    pred_idx = np.argmax(best_vgg_model.predict(arr, verbose=0), axis=1)[0]
    pred_label = tl_class_names[pred_idx]

    ax = plt.subplot(2, 3, i)
    plt.imshow(img)
    plt.title(f"True: {true_label}\nPred: {pred_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 23. Compare both approaches
#
# This final comparison summarizes the test loss and test accuracy of the improved CNN and the VGG16 transfer-learning model. It makes it easy to see which approach performed better on this dataset.

# %%
results = {
    "Improved CNN": {"test_loss": float(cnn_test_loss), "test_accuracy": float(cnn_test_acc)},
    "VGG16 Transfer Learning": {"test_loss": float(vgg_test_loss), "test_accuracy": float(vgg_test_acc)},
}

print("Model Comparison")
print("=" * 55)
print(f"{'Model':<25}{'Test Loss':>15}{'Test Accuracy':>15}")
print("=" * 55)
for model_name, vals in results.items():
    print(f"{model_name:<25}{vals['test_loss']:>15.4f}{vals['test_accuracy']:>15.4f}")
print("=" * 55)

if vgg_test_acc > cnn_test_acc:
    print("\nConclusion: Transfer learning with VGG16 performed better on this dataset.")
elif vgg_test_acc < cnn_test_acc:
    print("\nConclusion: The improved CNN trained from scratch performed better on this dataset.")
else:
    print("\nConclusion: Both models achieved the same test accuracy.")
# Out:
# Model Comparison
# =======================================================
# Model                          Test Loss  Test Accuracy
# =======================================================
# Improved CNN                      1.7149         0.2333
# VGG16 Transfer Learning           1.1743         0.7333
# =======================================================
#
# Conclusion: Transfer learning with VGG16 performed better on this dataset.
